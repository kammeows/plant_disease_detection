# %%
import os

def total_files(folder_path):
    try:
        return len([
            f for f in os.listdir(folder_path)
            if os.path.isfile(os.path.join(folder_path, f))
        ])
    except:
        print(" Path not found:", folder_path)
        return 0

# Base folder
BASE = r"E:\Sem-5\DL\plants_identification\archive"

# TRAIN
train_files_healthy =  os.path.join(BASE, "Train", "Train", "Healthy")
train_files_powdery =  os.path.join(BASE, "Train", "Train", "Powdery")
train_files_rust    =  os.path.join(BASE, "Train", "Train", "Rust")

# TEST
test_files_healthy =  os.path.join(BASE, "Test", "Test", "Healthy")
test_files_powdery =  os.path.join(BASE, "Test", "Test", "Powdery")
test_files_rust    =  os.path.join(BASE, "Test", "Test", "Rust")

# VALIDATION
valid_files_healthy = os.path.join(BASE, "Validation", "Validation", "Healthy")
valid_files_powdery = os.path.join(BASE, "Validation", "Validation", "Powdery")
valid_files_rust    = os.path.join(BASE, "Validation", "Validation", "Rust")

print("======== TRAIN SET ========")
print("Healthy:", total_files(train_files_healthy))
print("Powdery:", total_files(train_files_powdery))
print("Rust   :", total_files(train_files_rust))

print("\n======== TEST SET ========")
print("Healthy:", total_files(test_files_healthy))
print("Powdery:", total_files(test_files_powdery))
print("Rust   :", total_files(test_files_rust))

print("\n======== VALIDATION SET ========")
print("Healthy:", total_files(valid_files_healthy))
print("Powdery:", total_files(valid_files_powdery))
print("Rust   :", total_files(valid_files_rust))
# Out:
# ======== TRAIN SET ========
# Healthy: 458
# Powdery: 430
# Rust   : 434
#
# ======== TEST SET ========
# Healthy: 50
# Powdery: 50
# Rust   : 50
#
# ======== VALIDATION SET ========
# Healthy: 20
# Powdery: 20
# Rust   : 20

# %%
# ================================
# IMPORTS
# ================================
import os
from PIL import Image
import IPython.display as display

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# ================================
# CORRECT ABSOLUTE PATHS
# ================================
BASE = r"E:\Sem-5\DL\plants_identification\archive"

TRAIN_DIR = os.path.join(BASE, "Train", "Train")
VAL_DIR   = os.path.join(BASE, "Validation", "Validation")
TEST_DIR  = os.path.join(BASE, "Test", "Test")

print("TRAIN DIR:", TRAIN_DIR)
print("VAL DIR  :", VAL_DIR)
print("TEST DIR :", TEST_DIR)

# ================================
# PREVIEW SAMPLE IMAGES
# ================================
try:
    img1 = os.path.join(TRAIN_DIR, "Healthy", "8ce77048e12f3dd4.jpg")
    img2 = os.path.join(TRAIN_DIR, "Rust", "80f09587dfc7988e.jpg")

    with open(img1, "rb") as f:
        display.display(display.Image(data=f.read(), width=300))

    with open(img2, "rb") as f:
        display.display(display.Image(data=f.read(), width=300))
except:
    print("Skipping preview")

# ================================
# DATA GENERATORS
# ================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(225, 225),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(225, 225),
    batch_size=32,
    class_mode='categorical'
)

print("\nClass Mapping:", train_generator.class_indices)

# ================================
# MODEL
# ================================
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(225, 225, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(
    optimizer=Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ================================
# CALLBACKS
# ================================
checkpoint = ModelCheckpoint(
    "final_best_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# ================================
# TRAIN
# ================================
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator,
    callbacks=[checkpoint, early_stop]
)

print("\nTraining complete.")
print("Best model saved → final_best_model.h5")
# Out:
# TRAIN DIR: E:\Sem-5\DL\plants_identification\archive\Train\Train
# VAL DIR  : E:\Sem-5\DL\plants_identification\archive\Validation\Validation
# TEST DIR : E:\Sem-5\DL\plants_identification\archive\Test\Test
# Found 1322 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
#
# Class Mapping: {'Healthy': 0, 'Powdery': 1, 'Rust': 2}
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4562 - loss: 1.1014
# Epoch 1: val_accuracy improved from -inf to 0.61667, saving model to final_best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 234s 6s/step - accuracy: 0.4588 - loss: 1.0969 - val_accuracy: 0.6167 - val_loss: 0.7375
# Epoch 2/20
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# ================================
# PLOT ACCURACY GRAPH
# ================================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy vs Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# ================================
# PLOT LOSS GRAPH
# ================================
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ================================
# TEST ACCURACY
# ================================
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(225, 225),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_loss, test_acc = model.evaluate(test_generator)
print("\n📌 Test Accuracy:", test_acc * 100, "%")
# Out:
# Found 150 images belonging to 3 classes.
# C:\Users\aditi\anaconda3\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8470 - loss: 0.3700
#
# 📌 Test Accuracy: 80.66666722297668 %

# %%
# ================================
# CONFUSION MATRIX
# ================================
# Get predictions
y_true = test_generator.classes
y_pred = np.argmax(model.predict(test_generator), axis=1)

cm = confusion_matrix(y_true, y_pred)
labels = list(test_generator.class_indices.keys())

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels,
            yticklabels=labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ================================
# CLASSIFICATION REPORT
# ================================
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Healthy       0.66      0.90      0.76        50
#      Powdery       0.94      0.90      0.92        50
#         Rust       0.91      0.62      0.74        50
#
#     accuracy                           0.81       150
#    macro avg       0.84      0.81      0.81       150
# weighted avg       0.84      0.81      0.81       150

# %%
import matplotlib.pyplot as plt

train_counts = {
    'Healthy': total_files(train_files_healthy),
    'Powdery': total_files(train_files_powdery),
    'Rust': total_files(train_files_rust)
}

val_counts = {
    'Healthy': total_files(valid_files_healthy),
    'Powdery': total_files(valid_files_powdery),
    'Rust': total_files(valid_files_rust)
}

test_counts = {
    'Healthy': total_files(test_files_healthy),
    'Powdery': total_files(test_files_powdery),
    'Rust': total_files(test_files_rust)
}

# Bar chart for dataset distribution
plt.figure(figsize=(10,6))
plt.bar(train_counts.keys(), train_counts.values(), alpha=0.7, label='Train')
plt.bar(val_counts.keys(), val_counts.values(), alpha=0.7, label='Validation')
plt.bar(test_counts.keys(), test_counts.values(), alpha=0.7, label='Test')
plt.title("Dataset Image Distribution per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

folders = [train_files_healthy, train_files_powdery, train_files_rust]
class_names = ['Healthy', 'Powdery', 'Rust']

plt.figure(figsize=(12,6))

for i, folder in enumerate(folders):
    file = random.choice(os.listdir(folder))
    img_path = os.path.join(folder, file)
    img = mpimg.imread(img_path)

    plt.subplot(1, 3, i+1)
    plt.imshow(img)
    plt.title(class_names[i])
    plt.axis('off')

plt.suptitle("Sample Images from Each Class")
plt.show()

# %%
def show_prediction(img_path):
    img = Image.open(img_path).resize((225,225))
    plt.imshow(img)
    plt.axis('off')

    x = np.expand_dims(np.array(img)/255.0, axis=0)
    pred = model.predict(x)
    class_idx = np.argmax(pred)
    class_names = list(train_generator.class_indices.keys())

    plt.title(f"Prediction: {class_names[class_idx]}")
    plt.show()

# Example:
show_prediction(os.path.join(TEST_DIR, "Healthy", os.listdir(test_files_healthy)[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step

# %%
import matplotlib.pyplot as plt

# Dataset distribution
train_counts = {
    'Healthy': total_files(train_files_healthy),
    'Powdery': total_files(train_files_powdery),
    'Rust': total_files(train_files_rust)
}

val_counts = {
    'Healthy': total_files(valid_files_healthy),
    'Powdery': total_files(valid_files_powdery),
    'Rust': total_files(valid_files_rust)
}

test_counts = {
    'Healthy': total_files(test_files_healthy),
    'Powdery': total_files(test_files_powdery),
    'Rust': total_files(test_files_rust)
}

plt.figure(figsize=(10,6))
plt.bar(train_counts.keys(), train_counts.values(), alpha=0.7, label='Train')
plt.bar(val_counts.keys(), val_counts.values(), alpha=0.7, label='Validation')
plt.bar(test_counts.keys(), test_counts.values(), alpha=0.7, label='Test')
plt.title("Dataset Image Distribution per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.legend()
plt.grid(axis='y')
plt.savefig("dataset_distribution.png", dpi=300)
plt.show()

# %%
# Pick a random test image (Healthy class)
example_img = os.path.join(
    TEST_DIR,
    "Healthy",
    os.listdir(test_files_healthy)[0]
)

# %%
# AUTO-DETECT LAST CONV LAYER (recommended)
last_conv_layer = None
for layer in reversed(model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer.name
        break

print("Using last conv layer for Grad-CAM:", last_conv_layer)

gradcam(
    model,
    example_img,
    layer_name=last_conv_layer,
    save_as="gradcam_output.png"
)
# Out:
# Using last conv layer for Grad-CAM: conv2d_3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 10
#       6         break
#       8 print("Using last conv layer for Grad-CAM:", last_conv_layer)
# ---> 10 gradcam(
#      11     model,
#      12     example_img,
#      13     layer_name=last_conv_layer,
#      14     save_as="gradcam_output.png"
#      15 )
#
# Cell In[22], line 10, in gradcam(model, img_path, layer_name, save_as)
#       5 img = Image.open(img_path).resize((225,225))
#       6 x = np.expand_dims(np.array(img)/255.0, axis=0)
#       8 grad_model = tf.keras.models.Model(
#       9     [model.inputs],
# ---> 10     [model.get_layer(layer_name).output, model.output]
#      11 )
#      13 with tf.GradientTape() as tape:
#      15     conv_out, preds = grad_model(x)
#
# ...

# %%
print("\n================ MODEL SUMMARY ================\n")
model.summary()
# Out:
# ================ MODEL SUMMARY ================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 223, 223, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ...
